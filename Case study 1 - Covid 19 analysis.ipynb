# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing first dataset
covid19data=pd.read_csv("C:\\Users\\Anushree M\\Downloads\\data science\\data science\\Covid 19 data set\\covid19_Confirmed_dataset.csv")
covid19data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
covid19data.shape
# Out:
# (266, 104)

# %%
#deleting unnecessary columns
c19df=covid19data.drop(["Lat", "Long"], axis=1, inplace=True)

# %%
covid19data.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
#aggregating data column-wise 
c19data_agg=covid19data.groupby("Country/Region").sum()
# Out:
# C:\Temp\ipykernel_1100\3181233872.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   c19data_agg=covid19data.groupby("Country/Region").sum()

# %%
c19data_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
c19data_agg.shape
# Out:
# (187, 100)

# %%
#visualization of data country-wise
c19data_agg.loc["India"].plot()
c19data_agg.loc["Algeria"].plot()
c19data_agg.loc["Australia"].plot()
plt.legend()

# %%
#calculate a good measure 
c19data_agg.loc["China"].plot()
# Out:
# <Axes: >

# %%
c19data_agg.loc["China"][:7].plot()
# Out:
# <Axes: >

# %%
#calculate first derivatiev of the curve 
c19data_agg.loc["China"].diff().plot()
# Out:
# <Axes: >

# %%
#max infection rate
c19data_agg.loc["China"].diff().max()
# Out:
# 15136.0

# %%
#max infection rate for each of the countries
names=list(c19data_agg.index)
rate_df=[] #list of max infection rates of all countries
for i in colnames:
    rate_df.append(c19data_agg.loc[i].diff().max())
rate_df=pd.DataFrame(rate_df, index=names)
rate_df
# Out:
#                         0
# Afghanistan         232.0
# Albania              34.0
# Algeria             199.0
# Andorra              43.0
# Angola                5.0
# ...                   ...
# West Bank and Gaza   66.0
# Western Sahara        4.0
# Yemen                 5.0
# Zambia                9.0
# Zimbabwe              8.0
#
# [187 rows x 1 columns]

# %%
c19data_agg["Maximum infextion rates"]=rate_df
c19data_agg.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/22/20  \
# Country/Region                                           ...
# ...

# %%
#importing second dataset

happ_rep=pd.read_csv("C:\\Users\\Anushree M\\Downloads\\data science\\data science\\Covid 19 data set\\worldwide_happiness_report.csv")
happ_rep
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#drop useless columns 
useless=["Overall rank", "Score", "Generosity", "Perceptions of corruption"]
happ_rep.drop(useless, axis=1, inplace=True)
happ_rep
# Out:
#             Country or region  GDP per capita  Social support  \
# 0                     Finland           1.340           1.587
# 1                     Denmark           1.383           1.573
# 2                      Norway           1.488           1.582
# 3                     Iceland           1.380           1.624
# 4                 Netherlands           1.396           1.522
# ..                        ...             ...             ...
# 151                    Rwanda           0.359           0.711
# 152                  Tanzania           0.476           0.885
# 153               Afghanistan           0.350           0.517
# 154  Central African Republic           0.026           0.000
# 155               South Sudan           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices
# 0                      0.986                         0.596
# 1                      0.996                         0.592
# ...

# %%
happ_rep.set_index("Country or region", inplace=True)
happ_rep
# Out:
#                           GDP per capita  Social support  \
# Country or region
# Finland                            1.340           1.587
# Denmark                            1.383           1.573
# Norway                             1.488           1.582
# Iceland                            1.380           1.624
# Netherlands                        1.396           1.522
# ...                                  ...             ...
# Rwanda                             0.359           0.711
# Tanzania                           0.476           0.885
# Afghanistan                        0.350           0.517
# Central African Republic           0.026           0.000
# South Sudan                        0.306           0.575
#
#                           Healthy life expectancy  \
# Country or region
# Finland                                     0.986
# Denmark                                     0.996
# Norway                                      1.028
# ...

# %%
#joining the two data sets
rate_df.shape
# Out:
# (187, 1)

# %%
happ_rep.shape
# Out:
# (156, 4)

# %%
data=rate_df.join(happ_rep, how ='inner')
data
# Out:
#                  0  GDP per capita  Social support  Healthy life expectancy  \
# Afghanistan  232.0           0.350           0.517                    0.361
# Albania       34.0           0.947           0.848                    0.874
# Algeria      199.0           1.002           1.160                    0.785
# Argentina    291.0           1.092           1.432                    0.881
# Armenia      134.0           0.850           1.055                    0.815
# ...            ...             ...             ...                      ...
# Venezuela     29.0           0.960           1.427                    0.805
# Vietnam       19.0           0.741           1.346                    0.851
# Yemen          5.0           0.287           1.163                    0.463
# Zambia         9.0           0.578           1.058                    0.426
# Zimbabwe       8.0           0.366           1.114                    0.433
#
#              Freedom to make life choices
# ...

# %%
#creating a correlation maxtrix 
data.corr()
# Out:
#                                      0  GDP per capita  Social support  \
# 0                             1.000000        0.250118        0.191958
# GDP per capita                0.250118        1.000000        0.759468
# Social support                0.191958        0.759468        1.000000
# Healthy life expectancy       0.289263        0.863062        0.765286
# Freedom to make life choices  0.078196        0.394603        0.456246
#
#                               Healthy life expectancy  \
# 0                                            0.289263
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
#
#                               Freedom to make life choices
# 0                                                 0.078196
# GDP per capita                                    0.394603
# ...

# %%
#Visualization
x=data["GDP per capita"]
y=data[0]
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='0'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='0'>

# %%
x=data["Social support"]
y=data[0]
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='0'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='0'>

# %%
x=data["Healthy life expectancy"]
y=data[0]
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='0'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='0'>

# %%
x=data["Freedom to make life choices"]
y=data[0]
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='0'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='0'>
